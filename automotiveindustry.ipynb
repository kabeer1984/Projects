# %%
data['mpg'].value_counts(ascending=True) ## number of cars in different mpg category.
# Out:
# mpg
# 18.7    1
# 24.4    1
# 14.3    1
# 18.1    1
# 14.7    1
# 17.3    1
# 16.4    1
# 17.8    1
# 32.4    1
# 15.8    1
# 26.0    1
# 27.3    1
# 13.3    1
# 15.5    1
# 21.5    1
# 33.9    1
# 15.0    1
# 19.7    1
# 15.2    2
# 10.4    2
# 21.4    2
# 22.8    2
# 21.0    2
# 19.2    2
# 30.4    2
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\analytics\data\mtcars.csv")

# %%
data.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
data.shape
# Out:
# (32, 12)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
data[data['mpg']== 33.90]  ### max milage car of the table.
# Out:
#              model   mpg  cyl  disp  hp  drat     wt  qsec  vs  am  gear  carb
# 19  Toyota Corolla  33.9    4  71.1  65  4.22  1.835  19.9   1   1     4     1

# %%
data[data['mpg']== 10.40]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
#
#     gear  carb
# 14     3     4
# 15     3     4

# %%
## 2 cars that have least milage of the table.

# %%
data.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
###no null value found.

# %%
data['model'].nunique() ##number of different model cars
# Out:
# 32

# %%
data['model'].unique() ## name of all unique model cars of the table
# Out:
# array(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D',
#        'Merc 230', 'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL',
#        'Merc 450SLC', 'Cadillac Fleetwood', 'Lincoln Continental',
#        'Chrysler Imperial', 'Fiat 128', 'Honda Civic', 'Toyota Corolla',
#        'Toyota Corona', 'Dodge Challenger', 'AMC Javelin', 'Camaro Z28',
#        'Pontiac Firebird', 'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa',
#        'Ford Pantera L', 'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype=object)

# %%
data['gear'].value_counts() ## count of cars of different gear group.
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
data['cyl'].value_counts() ##number of cars of different cycle category
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
data[data['gear'] == '4'].shape[1]
# Out:
# 12

# %%
data[data['gear'] == '3'].shape[1]
# Out:
# 12

# %%
data[data['cyl'] == '4'].shape[1]
# Out:
# 12

# %%
data[data['cyl'] == '6'].shape[1]
# Out:
# 12

# %%
data[data['gear'] == '8'].shape[1]
# Out:
# 12

# %%
data.groupby('gear')['mpg'].mean() ### avarage mpg for different gear categories
# Out:
# gear
# 3    16.106667
# 4    24.533333
# 5    21.380000
# Name: mpg, dtype: float64

# %%
data.groupby('gear')['mpg' and'qsec'].mean()
# Out:
# gear
# 3    17.692
# 4    18.965
# 5    15.640
# Name: qsec, dtype: float64

# %%
data.groupby('cyl')['mpg'].mean()
# Out:
# cyl
# 4    26.663636
# 6    19.742857
# 8    15.100000
# Name: mpg, dtype: float64

# %%
data.groupby('cyl')['mpg' and 'qsec'].mean()
# Out:
# cyl
# 4    19.137273
# 6    17.977143
# 8    16.772143
# Name: qsec, dtype: float64

# %%
data.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
data.loc[data['mpg'].idxmax(), 'model',] ## other way to find max milage car model
# Out:
# 'Toyota Corolla'

# %%
data.loc[data['mpg'].idxmin(), 'model',] ## other way to find min milage car model
# Out:
# 'Cadillac Fleetwood'

# %%
data.loc[data.groupby('gear')['mpg'].idxmax()] ## top mpg cars in different gear categories
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
#
#     carb
# 20     1
# 19     1
# 27     2

# %%
data.groupby('gear')['mpg'].idxmax().apply(lambda x: data.loc[x, 'model']) ##cars model in different gear categories
# Out:
# gear
# 3     Toyota Corona
# 4    Toyota Corolla
# 5      Lotus Europa
# Name: mpg, dtype: object

# %%
data.nlargest(5, 'mpg') ## other way to find top mpg cars list withh all other information
# Out:
#              model   mpg  cyl  disp   hp  drat     wt   qsec  vs  am  gear  \
# 19  Toyota Corolla  33.9    4  71.1   65  4.22  1.835  19.90   1   1     4
# 17        Fiat 128  32.4    4  78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4  75.7   52  4.93  1.615  18.52   1   1     4
# 27    Lotus Europa  30.4    4  95.1  113  3.77  1.513  16.90   1   1     5
# 25       Fiat X1-9  27.3    4  79.0   66  4.08  1.935  18.90   1   1     4
#
#     carb
# 19     1
# 17     1
# 18     2
# 27     2
# 25     1

# %%
data['mpg'].value_counts().plot(kind='bar',color={'purple','blue'})

plt.xlabel('mpg')
plt.ylabel('gear')
plt.title('mpg by gear category')
plt.show()

# %%
data['model'].value_counts().plot(kind='bar',color={'green','yellow'})
plt.xlabel('model')
plt.ylabel('mpg')
plt.title('mpg by model')
plt.show()

# %%
from plotnine import ggplot,aes
from plotnine import geom_point, geom_col, geom_histogram, geom_boxplot, facet_grid, labs  #imp

# %%
ggplot(data) + aes(x="wt", y="mpg", size="hp", color='gear')  + geom_point()

# %%
ggplot(data) + aes(y="mpg")  + geom_boxplot()

# %%
ggplot(data) + facet_grid("~ gear") + aes(x='wt',y='mpg', color='am') + labs(x='Weight', y='Mileage') + geom_point()

# %%
ggplot(data) + aes(x="mpg") + geom_histogram(bins=5, color='green', fill='green')

# %%
(ggplot(data, aes(x="wt", y="mpg", fill="gear"))     + geom_point() )

# %%
###Histogram – Distribution of MPG

# %%
plt.hist(data['mpg'])
plt.xlabel('Miles Per Gallon')
plt.ylabel('Frequency')
plt.title('Distribution of MPG')
plt.show()

# %%
##Bar Chart – Average MPG by Cylinders

# %%
avg_mpg = data.groupby('cyl')['mpg'].mean()

avg_mpg.plot(kind='bar')
plt.xlabel('Cylinders')
plt.ylabel('Average MPG')
plt.title('Average MPG by Cylinders')
plt.show()

# %%
##Scatter Plot – Weight vs MPG

# %%
plt.scatter(data['wt'], data['mpg'])
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.title('Weight vs MPG')
plt.show()

# %%
##Box Plot – MPG by Number of Gears
sns.boxplot(x='gear', y='mpg', data=data)
plt.title('MPG by Gear')
plt.show()

# %%
##Line Plot – MPG trend by Car Index
plt.plot(data['mpg'])
plt.xlabel('Car Index')
plt.ylabel('MPG')
plt.title('MPG Trend')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
##📈 Shows variation across cars

# %%
##Pair Plot – Multiple Relationships
sns.pairplot(mtcars[['mpg','wt','hp','cyl']])
plt.show()
